# %%
import pandas as pd

pd.set_option("display.max_columns", None)

ruta = r"C:\Users\beabr\Downloads\OneDrive\Formaciones\Data Analyst & AI\Proyectos\flight_details.csv"
df_flight_details = pd.read_csv(ruta)

df_flight_details.sample(7)
# Out:
#             FL_DATE AIRLINE_CODE  FL_NUMBER ORIGIN DEST  CRS_DEP_TIME  \
# 2781142  2022-08-19           9E       4932    LEX  DTW          1530
# 694068   2022-11-22           9E       4677    CLT  LGA           700
# 2973713  2023-02-01           WN       2367    RNO  LAS           915
# 2512362  2019-06-07           OO       3077    ORD  GRB           820
# 2345155  2019-10-23           OO       5821    MSN  ORD          1306
# 1761462  2021-07-13           9E       4789    ATL  ABY          1030
# 2781318  2022-07-29           B6        891    BOS  TPA           710
#
#                         AIRLINE                 AIRLINE_DOT  DOT_CODE  \
# 2781142       Endeavor Air Inc.       Endeavor Air Inc.: 9E     20363
# 694068        Endeavor Air Inc.       Endeavor Air Inc.: 9E     20363
# 2973713  Southwest Airlines Co.  Southwest Airlines Co.: WN     19393
# 2512362   SkyWest Airlines Inc.   SkyWest Airlines Inc.: OO     20304
# ...

# %%
df_flight_details.shape
# Out:
# (3000000, 22)

# %%
print(f'Nuestro conjunto de datospresenta un conjunto de datos de {df_flight_details.shape[0]} filas y {df_flight_details.shape[1]} columnas')
# Out:
# Nuestro conjunto de datospresenta un conjunto de datos de 3000000 filas y 22 columnas

# %%
df_flight_details.info(show_counts=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   FL_DATE           3000000 non-null  str
#  1   AIRLINE_CODE      3000000 non-null  str
#  2   FL_NUMBER         3000000 non-null  int64
#  3   ORIGIN            3000000 non-null  str
#  4   DEST              3000000 non-null  str
#  5   CRS_DEP_TIME      3000000 non-null  int64
#  6   AIRLINE           3000000 non-null  str
#  7   AIRLINE_DOT       3000000 non-null  str
#  8   DOT_CODE          3000000 non-null  int64
#  9   ORIGIN_CITY       3000000 non-null  str
#  10  DEST_CITY         3000000 non-null  str
#  11  DEP_TIME          2922385 non-null  float64
#  12  TAXI_OUT          2921194 non-null  float64
#  13  WHEELS_OFF        2921194 non-null  float64
#  14  WHEELS_ON         2920056 non-null  float64
#  15  TAXI_IN           2920056 non-null  float64
# ...

# %%
df_flight_details.isnull().sum()
# Out:
# FL_DATE                 0
# AIRLINE_CODE            0
# FL_NUMBER               0
# ORIGIN                  0
# DEST                    0
# CRS_DEP_TIME            0
# AIRLINE                 0
# AIRLINE_DOT             0
# DOT_CODE                0
# ORIGIN_CITY             0
# DEST_CITY               0
# DEP_TIME            77615
# TAXI_OUT            78806
# WHEELS_OFF          78806
# WHEELS_ON           79944
# TAXI_IN             79944
# CRS_ARR_TIME            0
# ARR_TIME            79942
# CRS_ELAPSED_TIME       14
# ELAPSED_TIME        86198
# AIR_TIME            86198
# DISTANCE                0
# dtype: int64

# %%
df_flight_details.isnull().mean()*100
# Out:
# FL_DATE             0.000000
# AIRLINE_CODE        0.000000
# FL_NUMBER           0.000000
# ORIGIN              0.000000
# DEST                0.000000
# CRS_DEP_TIME        0.000000
# AIRLINE             0.000000
# AIRLINE_DOT         0.000000
# DOT_CODE            0.000000
# ORIGIN_CITY         0.000000
# DEST_CITY           0.000000
# DEP_TIME            2.587167
# TAXI_OUT            2.626867
# WHEELS_OFF          2.626867
# WHEELS_ON           2.664800
# TAXI_IN             2.664800
# CRS_ARR_TIME        0.000000
# ARR_TIME            2.664733
# CRS_ELAPSED_TIME    0.000467
# ELAPSED_TIME        2.873267
# AIR_TIME            2.873267
# DISTANCE            0.000000
# dtype: float64

# %%
df_flight_details.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df_flight_details.select_dtypes(include='object').columns:
    print(col.upper())
    print(df_flight_details[col].value_counts())
    print ('-------')
# Out:
# C:\Users\beabr\AppData\Local\Temp\ipykernel_14740\1635962819.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df_flight_details.select_dtypes(include='object').columns:
# FL_DATE
# FL_DATE
# 2019-07-25    2379
# 2019-08-02    2372
# 2019-12-01    2351
# 2019-08-23    2348
# 2019-07-30    2343
#               ...
# 2020-05-09     527
# 2020-05-16     525
# 2020-05-19     523
# 2020-05-12     523
# 2020-05-05     521
# Name: count, Length: 1704, dtype: int64
# -------
# AIRLINE_CODE
# AIRLINE_CODE
# WN    576470
# DL    395239
# AA    383106
# ...

# %%
def eda_preliminar (df_flight_details):
    display(df_flight_details.sample(5))
    
    print ('------------')
    print('DIMENSIONES')
    print(f'Nuestro conjunto de datos presenta un conjunto de datos de {df_flight_details.shape[0]} filas y {df_flight_details.shape[1]} columnas')

    print ('------------')
    print('INFO')
    display(df_flight_details.info())

    print ('------------')
    print('REVISIÓN NULOS')
    display (df_flight_details.isnull().mean()*100)

    print ('------------')
    print('REVISIÓN DUPLICADOS')
    print (F'Tenemos un total de {df_flight_details.duplicated().sum()} duplicados')

    print ('------------')
    print('FRECUENCAS CATEGÓRICAS')
    for col in df_flight_details.select_dtypes(include='object').columns:
        print(col.upper())
        print(df_flight_details[col].value_counts())
        print ('-------')

# %%
eda_preliminar(df_flight_details)
# Out:
#             FL_DATE AIRLINE_CODE  FL_NUMBER ORIGIN DEST  CRS_DEP_TIME  \
# 366513   2020-09-05           AA       2673    CLT  BUF           930
# 1128374  2020-06-22           WN       6904    DEN  FLL          1105
# 1539592  2022-11-10           F9        680    DEN  MCO           745
# 996525   2021-07-07           OH       5650    CLT  EWN           714
# 2843285  2023-06-13           UA       2189    ORD  BDL          1305
#
#                         AIRLINE                 AIRLINE_DOT  DOT_CODE  \
# 366513   American Airlines Inc.  American Airlines Inc.: AA     19805
# 1128374  Southwest Airlines Co.  Southwest Airlines Co.: WN     19393
# 1539592  Frontier Airlines Inc.  Frontier Airlines Inc.: F9     20436
# 996525        PSA Airlines Inc.       PSA Airlines Inc.: OH     20397
# 2843285   United Air Lines Inc.   United Air Lines Inc.: UA     19977
#
#            ORIGIN_CITY                       DEST_CITY  DEP_TIME  TAXI_OUT  \
# ...

# %%
import pandas as pd
from src import sp_eda

pd.set_option("display.max_columns", None)

ruta = r"C:\Users\beabr\Downloads\OneDrive\Formaciones\Data Analyst & AI\Proyectos\flight_details.csv"
df_flight_details = pd.read_csv(ruta)

sp_eda.eda_preliminar(df_flight_details)
# Out:
#             FL_DATE AIRLINE_CODE  FL_NUMBER ORIGIN DEST  CRS_DEP_TIME  \
# 2443198  2021-06-03           WN        466    SMF  LAX          1250
# 1660227  2019-08-03           OO       3733    MSP  IDA          1115
# 2668808  2023-06-21           UA       1409    IAH  EWR          2008
# 1575405  2019-12-29           YX       3494    IAH  CMH          1437
# 239447   2022-09-18           OH       5146    DTW  PHL           809
#
#                         AIRLINE                 AIRLINE_DOT  DOT_CODE  \
# 2443198  Southwest Airlines Co.  Southwest Airlines Co.: WN     19393
# 1660227   SkyWest Airlines Inc.   SkyWest Airlines Inc.: OO     20304
# 2668808   United Air Lines Inc.   United Air Lines Inc.: UA     19977
# 1575405        Republic Airline        Republic Airline: YX     20452
# 239447        PSA Airlines Inc.       PSA Airlines Inc.: OH     20397
#
#              ORIGIN_CITY         DEST_CITY  DEP_TIME  TAXI_OUT  WHEELS_OFF  \
# ...

# %%
df_flight_details["ORIGIN"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_flight_details["ORIGIN"].unique()
#
# NameError: name 'df_flight_details' is not defined
