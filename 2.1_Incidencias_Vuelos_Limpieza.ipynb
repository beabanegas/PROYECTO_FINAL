# %%
import sys
sys.path.append("src")

from sp_eda import eda_preliminar

# %%
import pandas as pd

# %%
ruta = r"C:\Users\beabr\Downloads\OneDrive\Formaciones\Data Analyst & AI\Proyectos\flight_delays.csv"
df = pd.read_csv(ruta)

eda_preliminar(df)

df_clean = df.copy()
# Out:
#             FL_DATE AIRLINE_CODE  FL_NUMBER ORIGIN  CRS_DEP_TIME  DEP_DELAY  \
# 604139   2020-03-06           9E       5034    MCI          1110       -4.0
# 1783411  2019-10-23           YV       6106    IAH          1835       -5.0
# 2876544  2021-09-16           9E       5082    DTW          2127       -5.0
# 111937   2022-08-24           OH       5063    LIT          1054       -4.0
# 954868   2020-03-01           UA        258    SFO           830       -6.0
#
#          ARR_DELAY  CANCELLED CANCELLATION_CODE  DIVERTED  DELAY_DUE_CARRIER  \
# 604139       -12.0        0.0               NaN       0.0                NaN
# 1783411      -23.0        0.0               NaN       0.0                NaN
# 2876544       -8.0        0.0               NaN       0.0                NaN
# 111937        -7.0        0.0               NaN       0.0                NaN
# 954868         0.0        0.0               NaN       0.0                NaN
#
# ...

# %%
df.sample(7)
# Out:
#             FL_DATE AIRLINE_CODE  FL_NUMBER ORIGIN  CRS_DEP_TIME  DEP_DELAY  \
# 602803   2019-11-14           UA        343    PBI          1650       -6.0
# 2794071  2021-11-28           G4        819    DSM           700       -2.0
# 2502215  2021-07-12           F9       2982    MIA          2120      248.0
# 1066092  2019-09-22           OO       3379    SMF          1710       -7.0
# 2158716  2022-07-04           OH       5022    CLE          1945      -11.0
# 1006525  2023-03-26           B6        125    JFK          1300      105.0
# 1425403  2023-07-07           DL       2805    EWR           620       -6.0
#
#          ARR_DELAY  CANCELLED CANCELLATION_CODE  DIVERTED  DELAY_DUE_CARRIER  \
# 602803       -10.0        0.0               NaN       0.0                NaN
# 2794071      -24.0        0.0               NaN       0.0                NaN
# 2502215      242.0        0.0               NaN       0.0               28.0
# ...

# %%
# En la limpieza de la base de datos anterior, vimos que era demasiado grande por lo que nos quedamos solo con ATL. 
# Hacemos lo mismo con esta antes de empezar a hacer nada más, para poder trabajar con una base de datos manejable

df_clean = df_clean[df_clean["ORIGIN"] == "ATL"].copy()

# %%
ruta_salida = r"C:\Users\beabr\Downloads\OneDrive\Formaciones\Data Analyst & AI\Proyectos\PROYECTO_FINAL\flight_delays_atl.csv"

df_clean.to_csv(ruta_salida, index=False)
