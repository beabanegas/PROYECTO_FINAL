# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

ruta = r"C:\Users\beabr\Downloads\OneDrive\Formaciones\Data Analyst & AI\Proyectos\PROYECTO_FINAL\flight_details_atl.csv"
df = pd.read_csv(ruta)

df.sample(7)
# Out:
#           FL_DATE AIRLINE_CODE  FL_NUMBER ORIGIN DEST  CRS_DEP_TIME  \
# 53315  2023-05-13           DL        895    ATL  LAX          1245
# 43876  2022-10-25           DL       2568    ATL  IAD          1340
# 74435  2020-08-06           DL       2507    ATL  LIT          2051
# 83559  2022-09-21           UA        297    ATL  IAH          1205
# 88851  2020-02-11           DL       2441    ATL  IND          1631
# 3882   2019-03-02           DL       2099    ATL  DCA          1111
# 72221  2019-12-26           OO       4048    ATL  TRI          1622
#
#                      AIRLINE                AIRLINE_DOT  DOT_CODE  \
# 53315   Delta Air Lines Inc.   Delta Air Lines Inc.: DL     19790
# 43876   Delta Air Lines Inc.   Delta Air Lines Inc.: DL     19790
# 74435   Delta Air Lines Inc.   Delta Air Lines Inc.: DL     19790
# 83559  United Air Lines Inc.  United Air Lines Inc.: UA     19977
# 88851   Delta Air Lines Inc.   Delta Air Lines Inc.: DL     19790
# 3882    Delta Air Lines Inc.   Delta Air Lines Inc.: DL     19790
# 72221  SkyWest Airlines Inc.  SkyWest Airlines Inc.: OO     20304
#
#        ORIGIN_CITY                           DEST_CITY  DEP_TIME  TAXI_OUT  \
# 53315  Atlanta, GA                     Los Angeles, CA    1253.0      16.0
# 43876  Atlanta, GA                      Washington, DC    1336.0      14.0
# 74435  Atlanta, GA                     Little Rock, AR    2048.0      15.0
# 83559  Atlanta, GA                         Houston, TX    1200.0      11.0
# 88851  Atlanta, GA                    Indianapolis, IN    1628.0      13.0
# 3882   Atlanta, GA                      Washington, DC    1111.0      16.0
# 72221  Atlanta, GA  Bristol/Johnson City/Kingsport, TN    1618.0      13.0
#
#        WHEELS_OFF  WHEELS_ON  TAXI_IN  CRS_ARR_TIME  ARR_TIME  \
# 53315      1309.0     1357.0     14.0          1430    1411.0
# 43876      1350.0     1511.0      7.0          1522    1518.0
# 74435      2103.0     2108.0      5.0          2120    2113.0
# 83559      1211.0     1245.0      8.0          1322    1253.0
# 88851      1641.0     1749.0      6.0          1803    1755.0
# 3882       1127.0     1247.0      4.0          1253    1251.0
# 72221      1631.0     1712.0      4.0          1731    1716.0
#
#        CRS_ELAPSED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE
# 53315             285.0         258.0     228.0    1947.0
# 43876             102.0         102.0      81.0     534.0
# 74435              89.0          85.0      65.0     453.0
# 83559             137.0         113.0      94.0     689.0
# 88851              92.0          87.0      68.0     432.0
# 3882              102.0         100.0      80.0     547.0
# 72221              69.0          58.0      41.0     227.0

# %%
df.dtypes
# Out:
# FL_DATE                 str
# AIRLINE_CODE            str
# FL_NUMBER             int64
# ORIGIN                  str
# DEST                    str
# CRS_DEP_TIME          int64
# AIRLINE                 str
# AIRLINE_DOT             str
# DOT_CODE              int64
# ORIGIN_CITY             str
# DEST_CITY               str
# DEP_TIME            float64
# TAXI_OUT            float64
# WHEELS_OFF          float64
# WHEELS_ON           float64
# TAXI_IN             float64
# CRS_ARR_TIME          int64
# ARR_TIME            float64
# CRS_ELAPSED_TIME    float64
# ELAPSED_TIME        float64
# AIR_TIME            float64
# DISTANCE            float64
# dtype: object

# %%
# Lo primero convertimos la columna de FL_DATE a tipo fecha

df["FL_DATE"] = pd.to_datetime(df["FL_DATE"], errors="coerce")

# %%
# Ahora convertimos las columnas que muestran horas en formato amigable, en principio no vamos a hacer operaciones con ellas, por lo que las mantenemos en formato "str" 

cols_hora = ["CRS_DEP_TIME", "DEP_TIME", "WHEELS_OFF", "WHEELS_ON", "CRS_ARR_TIME", "ARR_TIME"]

for col in cols_hora:
    s = pd.to_numeric(df[col], errors="coerce")
    s = s.apply(lambda x: f"{int(x):04d}" if pd.notna(x) else None)
    df[col] = pd.to_datetime(s, format="%H%M", errors="coerce").dt.strftime("%H:%M")

# %%
# Por ultimo transformamos las columnas que muestran una duración en minutos a Int64

cols_minutos = [
    "TAXI_OUT",
    "TAXI_IN",
    "CRS_ELAPSED_TIME",
    "ELAPSED_TIME",
    "AIR_TIME"
]

for col in cols_minutos:
    df[col] = pd.to_numeric(df[col], errors="coerce").round().astype("Int64")

# %%
df.dtypes
# Out:
# FL_DATE             datetime64[us]
# AIRLINE_CODE                   str
# FL_NUMBER                    int64
# ORIGIN                         str
# DEST                           str
# CRS_DEP_TIME                   str
# AIRLINE                        str
# AIRLINE_DOT                    str
# DOT_CODE                     int64
# ORIGIN_CITY                    str
# DEST_CITY                      str
# DEP_TIME                       str
# TAXI_OUT                     Int64
# WHEELS_OFF                     str
# WHEELS_ON                      str
# TAXI_IN                      Int64
# CRS_ARR_TIME                   str
# ARR_TIME                       str
# CRS_ELAPSED_TIME             Int64
# ELAPSED_TIME                 Int64
# AIR_TIME                     Int64
# DISTANCE                   float64
# dtype: object

# %%
df.isna().sum()
# Out:
# FL_DATE                0
# AIRLINE_CODE           0
# FL_NUMBER              0
# ORIGIN                 0
# DEST                   0
# CRS_DEP_TIME           0
# AIRLINE                0
# AIRLINE_DOT            0
# DOT_CODE               0
# ORIGIN_CITY            0
# DEST_CITY              0
# DEP_TIME            2457
# TAXI_OUT            2456
# WHEELS_OFF          2493
# WHEELS_ON           2574
# TAXI_IN             2485
# CRS_ARR_TIME           0
# ARR_TIME            2607
# CRS_ELAPSED_TIME       0
# ELAPSED_TIME        2807
# AIR_TIME            2807
# DISTANCE               0
# dtype: int64
