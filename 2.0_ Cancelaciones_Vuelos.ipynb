# %%
import pandas as pd
from src import sp_eda

pd.set_option("display.max_columns", None)

ruta = r"C:\Users\beabr\Downloads\OneDrive\Formaciones\Data Analyst & AI\Proyectos\flight_delays.csv"
df_flight_cancellation  = pd.read_csv(ruta)

sp_eda.eda_preliminar(df_flight_cancellation)
# Out:
#             FL_DATE AIRLINE_CODE  FL_NUMBER ORIGIN  CRS_DEP_TIME  DEP_DELAY  \
# 1155178  2022-01-26           AA       1744    TPA           804       -7.0
# 647055   2023-02-26           WN       1531    SNA          1400       15.0
# 1351384  2023-08-22           AA       1553    CLT           911       -4.0
# 1699104  2020-09-06           WN       2556    SAN          1045       -4.0
# 897424   2022-06-25           B6       1480    FLL           733       -8.0
#
#          ARR_DELAY  CANCELLED CANCELLATION_CODE  DIVERTED  DELAY_DUE_CARRIER  \
# 1155178        6.0        0.0               NaN       0.0                NaN
# 647055        14.0        0.0               NaN       0.0                NaN
# 1351384      -28.0        0.0               NaN       0.0                NaN
# 1699104      -17.0        0.0               NaN       0.0                NaN
# 897424        -5.0        0.0               NaN       0.0                NaN
#
# ...
